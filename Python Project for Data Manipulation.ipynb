# %% [markdown]
# ## Data Manipulation Project on Python (using Pandas)

# %%
import pandas as pd

df = pd.read_csv ('C://Users//Moises de la Rosa//Desktop//DataSet//Adidas.csv')

print (df)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast       New York
# 1     Foot Locker      1185732     1/2/2020  Northeast       New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       New York
# 3     Foot Locker      1185732     1/4/2020  Northeast       New York
# 4     Foot Locker      1185732     1/5/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# ## Find Correlation between fields

# %%
df.corr()
# Out:
#                   Retailer ID  Price per Unit  Units Sold  Total Sales  \
# Retailer ID          1.000000       -0.391684   -0.003194    -0.083580
# Price per Unit      -0.391684        1.000000    0.265869     0.435811
# Units Sold          -0.003194        0.265869    1.000000     0.913431
# Total Sales         -0.083580        0.435811    0.913431     1.000000
# Operating Profit    -0.027137        0.394546    0.892379     0.956307
# Operating Margin     0.216780       -0.137486   -0.305479    -0.364592
#
#                   Operating Profit  Operating Margin
# Retailer ID              -0.027137          0.216780
# Price per Unit            0.394546         -0.137486
# Units Sold                0.892379         -0.305479
# Total Sales               0.956307         -0.364592
# Operating Profit          1.000000         -0.211920
# Operating Margin         -0.211920          1.000000

# %% [markdown]
# ## Description of every field, offering a summary of the data (very useful to verify the integrity)

# %%
df.describe()
# Out:
#         Retailer ID  Price per Unit   Units Sold    Total Sales  \
# count  9.648000e+03     9648.000000  9648.000000    9648.000000
# mean   1.173850e+06       45.216625   256.930037   93273.437500
# std    2.636038e+04       14.705397   214.252030  141916.016727
# min    1.128299e+06        7.000000     0.000000       0.000000
# 25%    1.185732e+06       35.000000   106.000000    4254.500000
# 50%    1.185732e+06       45.000000   176.000000    9576.000000
# 75%    1.185732e+06       55.000000   350.000000  150000.000000
# max    1.197831e+06      110.000000  1275.000000  825000.000000
#
#        Operating Profit  Operating Margin
# count       9648.000000       9648.000000
# mean       34425.244761          0.422991
# std        54193.113713          0.097197
# min            0.000000          0.100000
# 25%         1921.752500          0.350000
# 50%         4371.420000          0.410000
# 75%        52062.500000          0.490000
# max       390000.000000          0.800000

# %% [markdown]
# ## Verify data type of every column in your dataframe

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   int64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   int64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 980.0+ KB
# None

# %% [markdown]
# ## Filter by columns

# %%
df[['Retailer', 'Retailer ID', 'Units Sold']]
# Out:
#          Retailer  Retailer ID  Units Sold
# 0     Foot Locker      1185732        1200
# 1     Foot Locker      1185732        1000
# 2     Foot Locker      1185732        1000
# 3     Foot Locker      1185732         850
# 4     Foot Locker      1185732         900
# ...           ...          ...         ...
# 9643  Foot Locker      1185732          64
# 9644  Foot Locker      1185732         105
# 9645  Foot Locker      1185732         184
# 9646  Foot Locker      1185732          70
# 9647  Foot Locker      1185732          83
#
# [9648 rows x 3 columns]

# %% [markdown]
# ## Filter columns by unique Values

# %%
df.Retailer.unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %% [markdown]
# ## Filter rows by an specific attribute

# %%
df[df['Retailer']=='Foot Locker']
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast       New York
# 1     Foot Locker      1185732     1/2/2020  Northeast       New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       New York
# 3     Foot Locker      1185732     1/4/2020  Northeast       New York
# 4     Foot Locker      1185732     1/5/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
## Filter data using iloc

# %%
df.iloc[14]
# Out:
# Retailer                        Foot Locker
# Retailer ID                         1185732
# Invoice Date                      1/27/2020
# Region                            Northeast
# State                              New York
# City                               New York
# Product             Women's Street Footwear
# Price per Unit                           40
# Units Sold                              950
# Total Sales                          380000
# Operating Profit                   133000.0
# Operating Margin                       0.35
# Sales Method                         Outlet
# Name: 14, dtype: object

# %%
df.iloc[14:17]
# Out:
#        Retailer  Retailer ID Invoice Date     Region     State      City  \
# 14  Foot Locker      1185732    1/27/2020  Northeast  New York  New York
# 15  Foot Locker      1185732    1/28/2020  Northeast  New York  New York
# 16  Foot Locker      1185732    1/29/2020  Northeast  New York  New York
#
#                       Product  Price per Unit  Units Sold  Total Sales  \
# 14    Women's Street Footwear              40         950       380000
# 15  Women's Athletic Footwear              45         800       360000
# 16              Men's Apparel              60         850       510000
#
#     Operating Profit  Operating Margin Sales Method
# 14          133000.0              0.35       Outlet
# 15          126000.0              0.35       Outlet
# 16          153000.0              0.30       Outlet

# %%
df.iloc[14,3]
# Out:
# 'Northeast'

# %%
## indexing with loc

# %%
region = df.copy()

region.set_index('Region', inplace=True)

region.head()
# Out:
#               Retailer  Retailer ID Invoice Date     State      City  \
# Region
# Northeast  Foot Locker      1185732     1/1/2020  New York  New York
# Northeast  Foot Locker      1185732     1/2/2020  New York  New York
# Northeast  Foot Locker      1185732     1/3/2020  New York  New York
# Northeast  Foot Locker      1185732     1/4/2020  New York  New York
# Northeast  Foot Locker      1185732     1/5/2020  New York  New York
#
#                              Product  Price per Unit  Units Sold  Total Sales  \
# Region
# Northeast      Men's Street Footwear              50        1200       600000
# Northeast    Men's Athletic Footwear              50        1000       500000
# Northeast    Women's Street Footwear              40        1000       400000
# Northeast  Women's Athletic Footwear              45         850       382500
# Northeast              Men's Apparel              60         900       540000
#
#            Operating Profit  Operating Margin Sales Method
# ...

# %%
region.loc['Northeast']
# Out:
#               Retailer  Retailer ID Invoice Date          State        City  \
# Region
# Northeast  Foot Locker      1185732     1/1/2020       New York    New York
# Northeast  Foot Locker      1185732     1/2/2020       New York    New York
# Northeast  Foot Locker      1185732     1/3/2020       New York    New York
# Northeast  Foot Locker      1185732     1/4/2020       New York    New York
# Northeast  Foot Locker      1185732     1/5/2020       New York    New York
# ...                ...          ...          ...            ...         ...
# Northeast  Foot Locker      1185732    1/24/2021  New Hampshire  Manchester
# Northeast  Foot Locker      1185732    1/24/2021  New Hampshire  Manchester
# Northeast  Foot Locker      1185732    2/22/2021  New Hampshire  Manchester
# Northeast  Foot Locker      1185732    2/22/2021  New Hampshire  Manchester
# Northeast  Foot Locker      1185732    2/22/2021  New Hampshire  Manchester
#
# ...

# %% [markdown]
# ## Drop Rows

# %%
import pandas as pd

df = pd.read_csv('C://Users//Moises de la Rosa//Desktop//DataSet//Adidas v2.csv')

print(df)
# Out:
#          Retailer  Retailer ID Invoice Date     Region         State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast  Pennsylvania
# 1     Foot Locker      1185732     1/1/2020  Northeast      New York
# 2     Foot Locker      1185732     1/1/2020  Northeast  Pennsylvania
# 3     Foot Locker      1185732     1/1/2020  Northeast  Pennsylvania
# 4     Foot Locker      1185732     1/1/2020  Northeast      New York
# ...           ...          ...          ...        ...           ...
# 9643       Amazon      1185732   12/31/2021  Northeast         Maine
# 9644       Amazon      1185732   12/31/2021  Northeast         Maine
# 9645  Foot Locker      1185732   12/31/2021  Northeast  Pennsylvania
# 9646  Foot Locker      1185732   12/31/2021  Northeast  Pennsylvania
# 9647  Foot Locker      1185732   12/31/2021  Northeast  Pennsylvania
#
#               City                Product  Price per Unit  Units Sold  \
# ...

# %%
df.isnull().sum()
# Out:
# Retailer             0
# Retailer ID          0
# Invoice Date         0
# Region               0
# State                0
# City                 0
# Product              0
# Price per Unit       0
# Units Sold           0
# Total Sales         10
# Operating Profit     0
# Operating Margin     0
# Sales Method         0
# dtype: int64

# %%
df.dropna(inplace=True)

df.isnull().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
## Drop Columns

# %%
import pandas as pd

df = pd.read_csv ('C://Users//Moises de la Rosa//Desktop//DataSet//Adidas.csv')

print (df)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast       New York
# 1     Foot Locker      1185732     1/2/2020  Northeast       New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       New York
# 3     Foot Locker      1185732     1/4/2020  Northeast       New York
# 4     Foot Locker      1185732     1/5/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df.drop('Sales Method', axis=1)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast       New York
# 1     Foot Locker      1185732     1/2/2020  Northeast       New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       New York
# 3     Foot Locker      1185732     1/4/2020  Northeast       New York
# 4     Foot Locker      1185732     1/5/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
## Create Calculated Columns

# %%
print(df)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast       New York
# 1     Foot Locker      1185732     1/2/2020  Northeast       New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       New York
# 3     Foot Locker      1185732     1/4/2020  Northeast       New York
# 4     Foot Locker      1185732     1/5/2020  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
## Create calculated columns

# %%
df['New Column'] = df['Price per Unit']*df['Units Sold']

df.head()


df.to_csv('output2.csv')

# %%
df[['Total Sales', 'New Column']]
# Out:
#       Total Sales  New Column
# 0          600000       60000
# 1          500000       50000
# 2          400000       40000
# 3          382500       38250
# 4          540000       54000
# ...           ...         ...
# 9643         3200        3200
# 9644         4305        4305
# 9645         7544        7544
# 9646         2940        2940
# 9647         2407        2407
#
# [9648 rows x 2 columns]

# %%
## Output file

# %%
df.to_csv('output.csv')
